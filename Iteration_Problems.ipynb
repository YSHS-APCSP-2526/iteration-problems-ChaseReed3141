# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/iteration-problems-ChaseReed3141/blob/main/Iteration_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem 0 Rotten Milk?
#
# Create a function called MilkRotten() that takes one argument DaysOld. DaysOld is a list of different milk cartons and how old they are. Your function is to iterate through the list DaysOld and
#
# 1. If the milk is less than 25 days old print "Milk is still good"
# 2. If milk is between 25 and 55 days old print "Milk is bad"
# 3. If the milk is older than 55 days old print "Call the Hazmat team"

# %%
for i in range(100):
  if i == 0:
    pass
  elif i == 13:
    print("FLAN")
  elif i % 6 == 0 and i % 7 == 0:
    print("FozzBozz")
  elif i % 6 == 0:
    print("Fozz")
  elif i % 7 == 0:
    print("Bozz")
  else:
    print (i)
# Out:
# 1
# 2
# 3
# 4
# 5
# Fozz
# Bozz
# 8
# 9
# 10
# 11
# Fozz
# FLAN
# Bozz
# 15
# 16
# 17
# Fozz
# 19
# 20
# Bozz
# 22
# 23
# Fozz
# 25
# 26
# 27
# Bozz
# 29
# Fozz
# 31
# 32
# 33
# 34
# Bozz
# Fozz
# 37
# 38
# 39
# 40
# 41
# FozzBozz
# 43
# 44
# 45
# 46
# 47
# Fozz
# Bozz
# 50
# 51
# 52
# 53
# Fozz
# 55
# Bozz
# 57
# 58
# 59
# Fozz
# 61
# 62
# Bozz
# 64
# 65
# Fozz
# 67
# 68
# 69
# Bozz
# 71
# Fozz
# 73
# 74
# 75
# 76
# Bozz
# Fozz
# 79
# 80
# 81
# 82
# 83
# FozzBozz
# 85
# 86
# 87
# 88
# 89
# Fozz
# Bozz
# 92
# 93
# 94
# 95
# Fozz
# 97
# Bozz
# 99

# %%
  for i in range(100):
    if i == 0:
      pass
    elif i % 3 == 0 and i % 5 == 0:
      print ("FizzBuzz")
    elif i % 3 == 0:
      print ("Fizz")
    elif i % 5 == 0:
      print ("Buzz")
    else:
      print (i)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz

# %%
DaysOld=[3,12,2,100,7,24,40,50,40,20,6,8]
#Insert Is MilkRotten() Function Here
def isMilkRotten(DaysOld):
  for i in DaysOld:
    if i < 25:
      print("Milk is still good")
    elif i < 56:
      print("Milk is bad ")
    else:
      print("Call the Hazmat Team!!!")

isMilkRotten(DaysOld)
# Out:
# Milk is still good
# Milk is still good
# Milk is still good
# Call the Hazmat Team!!!
# Milk is still good
# Milk is still good
# Milk is bad
# Milk is bad
# Milk is bad
# Milk is still good
# Milk is still good
# Milk is still good

# %% [markdown]
# #Problem 1: Number Lists
# Iterate through every number in a list to separate out even and odd numbers. Identify possible outlier values as well.
#
# ```python
# my_list = [1, 2, 3, 4, 5, 6, 7, 100, 110, 21, 33, 32, 2, 4]
#
#
# even = []
# not_even = []
# outlier = []
#
#
# #output
# even = [2, 4, 6, 32, 2, 4]
# not_even [1, 3, 5, 7, 21, 33]
# outliers [100, 110]
#
# ```

# %%
#Insert numberSorter() Function here.
def numberSorter(my_list):
  even = []
  odd =[]
  Q1 = len(my_list) / 4
  my_list.sort()
  for i in my_list:
    if i % 2 == 0:
      even.append(i)
    elif i % 1 == 0:
      odd.append(i)
  print(even)
  print(odd)


my_list = [1, 2, 3, 4, 5, 6, 7, 100, 110, 21, 33, 32, 2, 4]
numberSorter(my_list)
# Out:
# [2, 2, 4, 4, 6, 32, 100, 110]
# [1, 3, 5, 7, 21, 33]

# %% [markdown]
# #Modulo
#
# The percent symbol, %, in python is called the modulo. What the modulo does is it outputs the remainder from dividing two numbers. For instance.
#
# ```python
# 9 % 2
# ```
#
# would output 1
#
# ```python
# 10 % 2
# ```
# would output 0
#
# This can be a simple way to test if a number is even, n % 2 =0, or odd, n % 2 = 1.

# %% [markdown]
# #Problem 2: FizzBuzz
# Write a Python program which iterates the integers from 1 to 50. For multiples of three (i % 3 = 0) print "Fizz" instead of the number and for the multiples of five (i % 5 = 0) print "Buzz". For numbers which are multiples of both three and five print "FizzBuzz".

# %%
def FizzBuzz():
  if i == 0:
      pass
  elif i % 3 == 0 and i % 5 == 0:
    print ("FizzBuzz")
  elif i % 3 == 0:
    print ("Fizz")
  elif i % 5 == 0:
    print ("Buzz")
  else:
    print (i)

FizzBuzz()
# Out:
# Fizz

# %% [markdown]
# #Problem 3: Evens and a Skip
# Loop through and print out all even numbers from the numbers list in the same order they are received. Don't print any numbers that come after 237 in the sequence.

# %%
numbers = [
    951, 402, 984, 651, 360, 69, 408, 319, 601, 485, 980, 507, 725, 547, 544,
    615, 83, 165, 141, 501, 263, 617, 865, 575, 219, 390, 984, 592, 236, 105, 942, 941,
    386, 462, 47, 418, 907, 344, 236, 375, 823, 566, 597, 978, 328, 615, 953, 345,
    399, 162, 758, 219, 918, 237, 412, 566, 826, 248, 866, 950, 626, 949, 687, 217,
    815, 67, 104, 58, 512, 24, 892, 894, 767, 553, 81, 379, 843, 831, 445, 742, 717,
    958, 609, 842, 451, 688, 753, 854, 685, 93, 857, 440, 380, 126, 721, 328, 753, 470,
    743, 527
]
for i in numbers:
  if i == 237:
    break
  elif i % 2 == 0:
    print(i)
# Out:
# 402
# 984
# 360
# 408
# 980
# 544
# 390
# 984
# 592
# 236
# 942
# 386
# 462
# 418
# 344
# 236
# 566
# 978
# 328
# 162
# 758
# 918

# %% [markdown]
# ##Problem 4: String Splosion
#
# Given a  string like "Code" return a string like "CCoCodCode".
#
# string_splosion('Code') → 'CCoCodCode'
# string_splosion('abc') → 'aababc'
# string_splosion('ab') → 'aab'

# %%
def stringSplosion(word):
  output = word[0] + word[0] + word[1] + word[0] + word[1] + word[2] + word[0] + word[1:]
  print(output)
stringSplosion("Code")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-1347923971.py in <cell line: 0>()
#       2   output = word[0] + word[0] + word[1] + word[0] + word[1] + word[2] + word[0] + word[1:]
#       3   print(output)
# ----> 4 stringSplosion("ab")
#
# /tmp/ipython-input-1347923971.py in stringSplosion(word)
#       1 def stringSplosion(word):
# ----> 2   output = word[0] + word[0] + word[1] + word[0] + word[1] + word[2] + word[0] + word[1:]
#       3   print(output)
#       4 stringSplosion("ab")
#
# IndexError: string index out of range

# %% [markdown]
# ##Problem 5: Seven Dwarfs?
# You are to create a function that will go through a list of potential dwarf names and welcome all of the real dwarfs and reject the false dwarf.
#
# For example
# ```python
# SevenDwarf = ['happy','doc','bashful',’Sad’]
#
# #output
#
# 'welcome happy!','welcome doc!','welcome bashful!', 'IMPOSTER!'
#
# '''
